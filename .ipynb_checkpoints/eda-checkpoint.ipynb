# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import random
random.seed(100)
import warnings

# %%
df= pd.read_csv('turnip_price.csv')

# %%
df
# Out:
#           date  price  am_pm  purchase  user_code
# 0    3/29/2020    103      0         1          0
# 1    3/30/2020     81      0         0          0
# 2    3/30/2020    124      1         0          0
# 3    3/31/2020    101      0         0          0
# 4    3/31/2020    157      1         0          0
# ..         ...    ...    ...       ...        ...
# 178  4/23/2020    111      0         0          3
# 179  4/23/2020     97      1         0          3
# 180  4/24/2020     74      0         0          3
# 181  4/24/2020     58      1         0          3
# 182  4/25/2020    138      1         0          3
#
# [183 rows x 5 columns]

# %%
#df.loc[118, "user_code"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       183 non-null    object
#  1   price      183 non-null    int64
#  2   am_pm      183 non-null    int64
#  3   purchase   183 non-null    int64
#  4   user_code  183 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.3+ KB

# %%
df.groupby(["user_code"]).size()
# Out:
# user_code
# 0    74
# 1    45
# 2    35
# 3    29
# dtype: int64

# %%
user0_price = df[:74]
user1_price = df[74:119]
user2_price = df[119:154]
user3_price = df[154:]

# %%
print(len(user0_price["purchase"]!=0))
print(len(user1_price["purchase"]!=0))
print(len(user2_price["purchase"]!=0))
print(len(user3_price["purchase"]!=0))
# Out:
# 74
# 45
# 35
# 29

# %%
user0_price.head(3)
# Out:
#         date  price  am_pm  purchase  user_code
# 0  3/29/2020    103      0         1          0
# 1  3/30/2020     81      0         0          0
# 2  3/30/2020    124      1         0          0

# %%
user1_price.head(3)
# Out:
#          date  price  am_pm  purchase  user_code
# 74  3/29/2020     99      0         1          1
# 75  3/30/2020     69      0         0          1
# 76  3/30/2020     65      1         0          1

# %%
user2_price.head(30)# monday am start
# Out:
#           date  price  am_pm  purchase  user_code
# 119  4/06/2020     53      0         0          2
# 120  4/06/2020     43      1         0          2
# 121  4/07/2020     48      0         0          2
# 122  4/07/2020     41      1         0          2
# 123  4/08/2020    141      0         0          2
# 124  4/08/2020    148      1         0          2
# 125  4/09/2020    141      0         0          2
# 126  4/09/2020    144      1         0          2
# 127  4/10/2020    132      0         0          2
# 128  4/10/2020    144      1         0          2
# 129  4/11/2020    106      0         0          2
# 130  4/11/2020     67      1         0          2
# 131  4/13/2020     44      0         0          2
# 132  4/13/2020     48      1         0          2
# 133  4/14/2020    108      0         0          2
# 134  4/14/2020    122      1         0          2
# 135  4/15/2020    141      0         0          2
# 136  4/15/2020    142      1         0          2
# ...

# %%
user3_price.head(10)# thursday pm start
# Out:
#           date  price  am_pm  purchase  user_code
# 154  4/09/2020    184      1         0          3
# 155  4/10/2020    140      0         0          3
# 156  4/10/2020     70      1         0          3
# 157  4/11/2020     74      0         0          3
# 158  4/11/2020     62      1         0          3
# 159  4/12/2020     99      0         1          3
# 160  4/13/2020     73      0         0          3
# 161  4/13/2020     69      1         0          3
# 162  4/14/2020     67      0         0          3
# 163  4/14/2020     62      1         0          3

# %%
user0_price = user0_price.loc[:,"price"]
user1_price = user1_price.loc[:,"price"]
user2_price = user2_price.loc[:,"price"]
user3_price = user3_price.loc[:,"price"]

# %%
#user0_price

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlabel ("user 0 Trend", fontsize=18)
ax.set_ylabel ("Price", fontsize=18);
user0_price.plot(lw=3);

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlabel ("user 1 Trend", fontsize=18)
ax.set_ylabel ("Price", fontsize=18);
user1_price.plot(lw=3);

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlabel ("user 2 Trend", fontsize=18)
ax.set_ylabel ("Price", fontsize=18);
user2_price.plot(lw=3);

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.set_xlabel ("user 3 Trend", fontsize=18)
ax.set_ylabel ("Price", fontsize=18);
user3_price.plot(lw=3);
